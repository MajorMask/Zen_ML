# %%
# %pip install "zenml[server]"
# !zenml integration install sklearn -y
# %pip install pyparsing==2.4.2 

import IPython

IPython.Application.instance().kernel.do_shutdown(restart=True)
# Out:
# Collecting zenml[server]
#   Downloading zenml-0.47.0-py3-none-any.whl (6.1 MB)
#                                               0.0/6.1 MB ? eta -:--:--
#                                               0.0/6.1 MB ? eta -:--:--
#                                               0.0/6.1 MB 262.6 kB/s eta 0:00:24
#                                               0.0/6.1 MB 326.8 kB/s eta 0:00:19
#                                               0.1/6.1 MB 722.1 kB/s eta 0:00:09
#      -                                        0.3/6.1 MB 1.3 MB/s eta 0:00:05
#      ---                                      0.5/6.1 MB 1.9 MB/s eta 0:00:03
#      ---                                      0.5/6.1 MB 1.6 MB/s eta 0:00:04
#      -----                                    0.8/6.1 MB 2.4 MB/s eta 0:00:03
#      ------                                   0.9/6.1 MB 2.4 MB/s eta 0:00:03
#      -------                                  1.1/6.1 MB 2.6 MB/s eta 0:00:02
#      --------                                 1.3/6.1 MB 2.7 MB/s eta 0:00:02
#      ---------                                1.5/6.1 MB 2.9 MB/s eta 0:00:02
#      ----------                               1.6/6.1 MB 2.8 MB/s eta 0:00:02
#      ------------                             1.9/6.1 MB 2.9 MB/s eta 0:00:02
#      -------------                            2.0/6.1 MB 3.0 MB/s eta 0:00:02
#      ---------------                          2.4/6.1 MB 3.3 MB/s eta 0:00:02
#      ----------------                         2.5/6.1 MB 3.2 MB/s eta 0:00:02
#      -----------------                        2.6/6.1 MB 3.2 MB/s eta 0:00:02
#      ------------------                       2.8/6.1 MB 3.3 MB/s eta 0:00:01
#      -------------------                      3.0/6.1 MB 3.3 MB/s eta 0:00:01
#      ---------------------                    3.3/6.1 MB 3.5 MB/s eta 0:00:01
#      -----------------------                  3.5/6.1 MB 3.5 MB/s eta 0:00:01
#      ------------------------                 3.7/6.1 MB 3.6 MB/s eta 0:00:01
#      --------------------------               4.0/6.1 MB 3.7 MB/s eta 0:00:01
#      ----------------------------             4.3/6.1 MB 3.8 MB/s eta 0:00:01
#      -----------------------------            4.6/6.1 MB 3.9 MB/s eta 0:00:01
#      -------------------------------          4.9/6.1 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------        5.2/6.1 MB 4.1 MB/s eta 0:00:01
#      -----------------------------------      5.4/6.1 MB 4.1 MB/s eta 0:00:01
#      --------------------------------------   5.8/6.1 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------  6.1/6.1 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------- 6.1/6.1 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (3.1.2)
# Collecting alembic<1.9.0,>=1.8.1 (from zenml[server])
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#                                               0.0/209.8 kB ? eta -:--:--
#      -------------------------------------- 209.8/209.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: azure-mgmt-resource>=21.0.0 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (22.0.0)
# Collecting click<8.1.4,>=8.0.1 (from zenml[server])
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#                                               0.0/96.6 kB ? eta -:--:--
#      ---------------------------------------- 96.6/96.6 kB 5.4 MB/s eta 0:00:00
# Collecting click-params<0.4.0,>=0.3.0 (from zenml[server])
#   Downloading click_params-0.3.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: cloudpickle<3,>=2.0.0 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (2.2.1)
# Collecting distro<2.0.0,>=1.6.0 (from zenml[server])
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: docker<6.2.0,>=6.1.0 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (6.1.3)
# Requirement already satisfied: fastapi<0.100,>=0.75 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (0.89.1)
# Collecting fastapi-utils<0.3.0,>=0.2.1 (from zenml[server])
#   Downloading fastapi_utils-0.2.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.18 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (3.1.37)
# Collecting httplib2<0.20,>=0.19.1 (from zenml[server])
#   Downloading httplib2-0.19.1-py3-none-any.whl (95 kB)
#                                               0.0/95.4 kB ? eta -:--:--
#      ---------------------------------------- 95.4/95.4 kB 5.3 MB/s eta 0:00:00
# Collecting ipinfo>=4.4.3 (from zenml[server])
#   Downloading ipinfo-4.4.3-py3-none-any.whl (24 kB)
# Collecting orjson<3.9.0,>=3.8.3 (from zenml[server])
#   Downloading orjson-3.8.14-cp311-none-win_amd64.whl (190 kB)
#                                               0.0/190.2 kB ? eta -:--:--
#      ------------------------------------- 190.2/190.2 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.5 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (2.1.1)
# Collecting passlib[bcrypt]<1.8.0,>=1.7.4 (from zenml[server])
#   Downloading passlib-1.7.4-py2.py3-none-any.whl (525 kB)
#                                               0.0/525.6 kB ? eta -:--:--
#      ----------------                       225.3/525.6 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------  522.2/525.6 kB 5.4 MB/s eta 0:00:01
#      -------------------------------------- 525.6/525.6 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (5.9.0)
# Requirement already satisfied: pydantic<1.11,>=1.9.0 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (1.10.13)
# Collecting pyjwt[crypto]==2.7.* (from zenml[server])
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting pymysql<1.1.0,>=1.0.2 (from zenml[server])
#   Downloading PyMySQL-1.0.3-py3-none-any.whl (43 kB)
#                                               0.0/43.7 kB ? eta -:--:--
#      ---------------------------------------- 43.7/43.7 kB ? eta 0:00:00
# Collecting pyparsing<3,>=2.4.0 (from zenml[server])
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#                                               0.0/67.8 kB ? eta -:--:--
#      ---------------------------------------- 67.8/67.8 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (2.8.2)
# Collecting python-multipart<0.1.0,>=0.0.5 (from zenml[server])
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#                                               0.0/45.7 kB ? eta -:--:--
#      ---------------------------------------- 45.7/45.7 kB ? eta 0:00:00
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (6.0.1)
# Collecting rich[jupyter]>=12.0.0 (from zenml[server])
#   Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#                                               0.0/240.6 kB ? eta -:--:--
#      -------------------------------------- 240.6/240.6 kB 4.9 MB/s eta 0:00:00
# Collecting sqlalchemy_utils==0.38.3 (from zenml[server])
#   Downloading SQLAlchemy_Utils-0.38.3-py3-none-any.whl (100 kB)
#                                               0.0/100.3 kB ? eta -:--:--
#      -------------------------------------- 100.3/100.3 kB 5.6 MB/s eta 0:00:00
# Collecting sqlmodel==0.0.8 (from zenml[server])
#   Downloading sqlmodel-0.0.8-py3-none-any.whl (21 kB)
# Requirement already satisfied: uvicorn[standard]>=0.17.5 in c:\users\manan\miniconda3\lib\site-packages (from zenml[server]) (0.23.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\manan\miniconda3\lib\site-packages (from pyjwt[crypto]==2.7.*->zenml[server]) (39.0.1)
# Requirement already satisfied: SQLAlchemy>=1.3 in c:\users\manan\miniconda3\lib\site-packages (from sqlalchemy_utils==0.38.3->zenml[server]) (2.0.21)
# Collecting SQLAlchemy>=1.3 (from sqlalchemy_utils==0.38.3->zenml[server])
#   Downloading SQLAlchemy-1.4.41-cp311-cp311-win_amd64.whl (1.6 MB)
#                                               0.0/1.6 MB ? eta -:--:--
#      -------                                  0.3/1.6 MB 8.9 MB/s eta 0:00:01
#      -------------                            0.5/1.6 MB 6.4 MB/s eta 0:00:01
#      --------------------                     0.8/1.6 MB 6.2 MB/s eta 0:00:01
#      ---------------------------              1.1/1.6 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------        1.3/1.6 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  1.6/1.6 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 5.9 MB/s eta 0:00:00
# Collecting sqlalchemy2-stubs (from sqlmodel==0.0.8->zenml[server])
#   Downloading sqlalchemy2_stubs-0.0.2a37-py3-none-any.whl (191 kB)
#                                               0.0/191.7 kB ? eta -:--:--
#      ------------------------------------- 191.7/191.7 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: Mako in c:\users\manan\miniconda3\lib\site-packages (from alembic<1.9.0,>=1.8.1->zenml[server]) (1.2.4)
# Requirement already satisfied: msrest>=0.7.1 in c:\users\manan\miniconda3\lib\site-packages (from azure-mgmt-resource>=21.0.0->zenml[server]) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in c:\users\manan\miniconda3\lib\site-packages (from azure-mgmt-resource>=21.0.0->zenml[server]) (1.1.28)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in c:\users\manan\miniconda3\lib\site-packages (from azure-mgmt-resource>=21.0.0->zenml[server]) (1.4.0)
# Requirement already satisfied: colorama in c:\users\manan\miniconda3\lib\site-packages (from click<8.1.4,>=8.0.1->zenml[server]) (0.4.6)
# Collecting validators<0.19,>=0.18 (from click-params<0.4.0,>=0.3.0->zenml[server])
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging>=14.0 in c:\users\manan\miniconda3\lib\site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (23.0)
# Requirement already satisfied: requests>=2.26.0 in c:\users\manan\miniconda3\lib\site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (2.29.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\manan\miniconda3\lib\site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (1.26.16)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\manan\miniconda3\lib\site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (1.6.3)
# Requirement already satisfied: pywin32>=304 in c:\users\manan\miniconda3\lib\site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (305.1)
# Requirement already satisfied: starlette==0.22.0 in c:\users\manan\miniconda3\lib\site-packages (from fastapi<0.100,>=0.75->zenml[server]) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\manan\miniconda3\lib\site-packages (from starlette==0.22.0->fastapi<0.100,>=0.75->zenml[server]) (4.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\manan\miniconda3\lib\site-packages (from gitpython<4.0.0,>=3.1.18->zenml[server]) (4.0.10)
# Requirement already satisfied: cachetools in c:\users\manan\miniconda3\lib\site-packages (from ipinfo>=4.4.3->zenml[server]) (5.3.1)
# Requirement already satisfied: aiohttp<=4 in c:\users\manan\miniconda3\lib\site-packages (from ipinfo>=4.4.3->zenml[server]) (3.8.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\manan\miniconda3\lib\site-packages (from pandas>=1.1.5->zenml[server]) (1.26.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manan\miniconda3\lib\site-packages (from pandas>=1.1.5->zenml[server]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\manan\miniconda3\lib\site-packages (from pandas>=1.1.5->zenml[server]) (2023.3)
# Requirement already satisfied: bcrypt>=3.1.0 in c:\users\manan\miniconda3\lib\site-packages (from passlib[bcrypt]<1.8.0,>=1.7.4->zenml[server]) (4.0.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\manan\miniconda3\lib\site-packages (from pydantic<1.11,>=1.9.0->zenml[server]) (4.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\manan\miniconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.1->zenml[server]) (1.16.0)
# Collecting ipywidgets<9,>=7.5.1 (from rich[jupyter]>=12.0.0->zenml[server])
#   Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#                                               0.0/139.4 kB ? eta -:--:--
#      -------------------------------------- 139.4/139.4 kB 4.2 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0 (from rich[jupyter]>=12.0.0->zenml[server])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#                                               0.0/87.5 kB ? eta -:--:--
#      ---------------------------------------- 87.5/87.5 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\manan\miniconda3\lib\site-packages (from rich[jupyter]>=12.0.0->zenml[server]) (2.16.1)
# Requirement already satisfied: h11>=0.8 in c:\users\manan\miniconda3\lib\site-packages (from uvicorn[standard]>=0.17.5->zenml[server]) (0.14.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.17.5->zenml[server])
#   Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl (55 kB)
#                                               0.0/55.4 kB ? eta -:--:--
#      ---------------------------------------- 55.4/55.4 kB ? eta 0:00:00
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\manan\miniconda3\lib\site-packages (from uvicorn[standard]>=0.17.5->zenml[server]) (1.0.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.17.5->zenml[server])
#   Downloading watchfiles-0.21.0-cp311-none-win_amd64.whl (280 kB)
#                                               0.0/280.1 kB ? eta -:--:--
#      -------------------------------------  276.5/280.1 kB 8.3 MB/s eta 0:00:01
#      -------------------------------------- 280.1/280.1 kB 5.7 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.17.5->zenml[server])
#   Downloading websockets-12.0-cp311-cp311-win_amd64.whl (124 kB)
#                                               0.0/125.0 kB ? eta -:--:--
#      -------------------------------------- 125.0/125.0 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manan\miniconda3\lib\site-packages (from Jinja2->zenml[server]) (2.1.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\manan\miniconda3\lib\site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\manan\miniconda3\lib\site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\manan\miniconda3\lib\site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\manan\miniconda3\lib\site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\manan\miniconda3\lib\site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\manan\miniconda3\lib\site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\manan\miniconda3\lib\site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.3.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.2 in c:\users\manan\miniconda3\lib\site-packages (from azure-mgmt-core<2.0.0,>=1.3.2->azure-mgmt-resource>=21.0.0->zenml[server]) (1.29.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\manan\miniconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]==2.7.*->zenml[server]) (1.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\manan\miniconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.18->zenml[server]) (5.0.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\manan\miniconda3\lib\site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\manan\miniconda3\lib\site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (8.17.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\manan\miniconda3\lib\site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (5.13.0)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server])
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#                                               0.0/2.3 MB ? eta -:--:--
#      -----                                    0.3/2.3 MB 6.2 MB/s eta 0:00:01
#      ---------                                0.5/2.3 MB 6.8 MB/s eta 0:00:01
#      --------------                           0.8/2.3 MB 6.5 MB/s eta 0:00:01
#      ------------------                       1.1/2.3 MB 6.2 MB/s eta 0:00:01
#      -----------------------                  1.3/2.3 MB 6.1 MB/s eta 0:00:01
#      ---------------------------              1.6/2.3 MB 6.0 MB/s eta 0:00:01
#      --------------------------------         1.9/2.3 MB 6.0 MB/s eta 0:00:01
#      -------------------------------------    2.1/2.3 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  2.3/2.3 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------- 2.3/2.3 MB 5.6 MB/s eta 0:00:00
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server])
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#                                               0.0/214.9 kB ? eta -:--:--
#      -------------------------------------- 214.9/214.9 kB 4.4 MB/s eta 0:00:00
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich[jupyter]>=12.0.0->zenml[server])
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manan\miniconda3\lib\site-packages (from msrest>=0.7.1->azure-mgmt-resource>=21.0.0->zenml[server]) (2023.11.17)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\manan\miniconda3\lib\site-packages (from msrest>=0.7.1->azure-mgmt-resource>=21.0.0->zenml[server]) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\manan\miniconda3\lib\site-packages (from msrest>=0.7.1->azure-mgmt-resource>=21.0.0->zenml[server]) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manan\miniconda3\lib\site-packages (from requests>=2.26.0->docker<6.2.0,>=6.1.0->zenml[server]) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\manan\miniconda3\lib\site-packages (from SQLAlchemy>=1.3->sqlalchemy_utils==0.38.3->zenml[server]) (3.0.0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\manan\miniconda3\lib\site-packages (from validators<0.19,>=0.18->click-params<0.4.0,>=0.3.0->zenml[server]) (5.1.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\manan\miniconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<0.100,>=0.75->zenml[server]) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\manan\miniconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]==2.7.*->zenml[server]) (2.21)
# Requirement already satisfied: jedi>=0.16 in c:\users\manan\miniconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\manan\miniconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\manan\miniconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (3.0.41)
# Requirement already satisfied: stack-data in c:\users\manan\miniconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\manan\miniconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.7.1->azure-mgmt-resource>=21.0.0->zenml[server]) (3.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\manan\miniconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\manan\miniconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in c:\users\manan\miniconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\manan\miniconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\manan\miniconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.2)
# Installing collected packages: passlib, widgetsnbextension, websockets, validators, sqlalchemy2-stubs, SQLAlchemy, python-multipart, pyparsing, pymysql, pyjwt, orjson, mdurl, jupyterlab-widgets, httptools, distro, click, watchfiles, sqlmodel, sqlalchemy_utils, markdown-it-py, httplib2, click-params, alembic, rich, ipinfo, ipywidgets, fastapi-utils, zenml
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.21
#     Uninstalling SQLAlchemy-2.0.21:
#       Successfully uninstalled SQLAlchemy-2.0.21
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.8.0
#     Uninstalling PyJWT-2.8.0:
#       Successfully uninstalled PyJWT-2.8.0
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.9.7
#     Uninstalling orjson-3.9.7:
#       Successfully uninstalled orjson-3.9.7
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: alembic
#     Found existing installation: alembic 1.12.0
#     Uninstalling alembic-1.12.0:
#       Successfully uninstalled alembic-1.12.0
# Successfully installed SQLAlchemy-1.4.41 alembic-1.8.1 click-8.1.3 click-params-0.3.0 distro-1.8.0 fastapi-utils-0.2.1 httplib2-0.19.1 httptools-0.6.1 ipinfo-4.4.3 ipywidgets-8.1.1 jupyterlab-widgets-3.0.9 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.8.14 passlib-1.7.4 pyjwt-2.7.0 pymysql-1.0.3 pyparsing-2.4.7 python-multipart-0.0.6 rich-13.7.0 sqlalchemy2-stubs-0.0.2a37 sqlalchemy_utils-0.38.3 sqlmodel-0.0.8 validators-0.18.2 watchfiles-0.21.0 websockets-12.0 widgetsnbextension-4.0.9 zenml-0.47.0
# Note: you may need to restart the kernel to use updated packages.
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠴ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
# ⠼ Installing integrations...
# ⠦ Installing integrations...
# ⠧ Installing integrations...
# ⠇ Installing integrations...
# ⠏ Installing integrations...
# ⠋ Installing integrations...
# ⠙ Installing integrations...
# ⠹ Installing integrations...
# ⠸ Installing integrations...
#
# Collecting pyparsing==2.4.2
#   Downloading pyparsing-2.4.2-py2.py3-none-any.whl (65 kB)
#                                               0.0/65.5 kB ? eta -:--:--
#      ------                                   10.2/65.5 kB ? eta -:--:--
#      ------                                   10.2/65.5 kB ? eta -:--:--
#      -----------------                      30.7/65.5 kB 259.2 kB/s eta 0:00:01
#      -----------------------                41.0/65.5 kB 279.3 kB/s eta 0:00:01
#      -------------------------------------- 65.5/65.5 kB 351.7 kB/s eta 0:00:00
# Installing collected packages: pyparsing
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.7
#     Uninstalling pyparsing-2.4.7:
#       Successfully uninstalled pyparsing-2.4.7
# Successfully installed pyparsing-2.4.2
# Note: you may need to restart the kernel to use updated packages.
# {'status': 'ok', 'restart': True}
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !rm -rf .zen
# !zenml init
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.
# Initializing the ZenML global configuration version to 0.47.0
# ⠋ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠼ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠴ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠇ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠼ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠴ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠦ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠋ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠴ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠦ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠇ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠋ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠼ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠦ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠇ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠼ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠴ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠦ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠋ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠼ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠦ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠇ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠋ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠴ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
# Creating default workspace 'default' ...
# Creating default user 'default' ...
#
# ⠇ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠋ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
# Creating default stack for user 'default' in workspace default...
# Setting the global active workspace to 'default'.
# Setting the global active stack to default.
#
# ⠼ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
# Setting the repo active workspace to 'default'.
# Setting the repo active stack to default.
#
# ⠴ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠦ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠋ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
# Integration aws failed to register flavors. Error: No module named 'aws_profile_manager'
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠴ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠦ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠧ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠇ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠏ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠙ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
# Reloading configuration file D:\Machine Learning Projects\Zen_ML\.zen\config.yaml
#
# ZenML repository initialized at d:\Machine Learning Projects\Zen_ML.
# ⠹ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
# ⠸ Initializing ZenML repository at d:\Machine Learning Projects\Zen_ML.
#
#
# Reloading configuration file D:\Machine Learning Projects\Zen_ML\.zen\config.yaml
# The local active stack was initialized to 'default'. This local configuration
# will only take effect when you're running ZenML from the initialized repository
# root, or from a subdirectory. For more information on repositories and
# configurations, please visit
# https://docs.zenml.io/user-guide/starter-guide/understand-stacks.

# %%
import numpy as np
from sklearn.base import ClassifierMixin
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

def train_test() -> None:

    digits = load_digits()
    data = digits.images.reshape((len(digits.images),-1))
    X_train, X_test, y_train, y_test = train_test_split(
        data, digits.target, test_size = 0.2, shuffle = False
    )
    model = SVC(gamma = 0.001)
    model.fit(X_train, y_train)
    test_acc = model.score(X_test, y_test)
    print(f"Test accuracy: {test_acc}" )
    

train_test()
# Out:
# Test accuracy: 0.9583333333333334

# %%
from zenml import step
from typing_extensions import Annotated
import pandas as pd
from typing import Tuple

@step
def importer() ->[
    Annotated[np.ndarray, "X_train"],
    Annotated[np.ndarray, "X_test"],
    Annotated[np.ndarray, "y_train"],
    Annotated[np.ndarray, "y_test"],
]:
    
    # Loading the digits of the dataset as numpy arrays.
    data = digits.images.reshape((len(digits.images),-1))
    X_train, X_test, y_train, y_test = train_test_split(
        data, digits.target, test_size = 0.2, shuffle = False
    )
    return X_train, X_test, y_train, y_test
